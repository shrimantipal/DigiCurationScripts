# %%
import subprocess
import os
import sys
import shutil
import argparse
import xlrd
from openpyxl import Workbook
import markdown2
from weasyprint import HTML
import stat
import time
import pandas as pd
import soundfile as sf

# %%
current_dir = os.getcwd()
unoconv_path = os.path.join(current_dir, "Scripts", "unoconv")
print(unoconv_path)
# Out:
# C:\Users\pal10\Desktop\tkapp\Scripts\unoconv

# %%
def transform_file_path(file_path):

    components = file_path.split(os.sep)
    
    preservation_index = components.index('preservation')
    
    components[preservation_index] = r"access\nearline"
    access = r"access\nearline"
    new_file_path = os.sep.join(components[:-1])  # Remove the last directory
    #new_file_path = os.path.join(new_file_path, access)
    print(new_file_path)
    return new_file_path

def conversion_log_modify(name, input, output, format):
    global conversion_log
    file_stat = os.stat(input)
    print(file_stat)
    print(name)
    creation_time = file_stat.st_mtime
    # Convert to a human-readable format
    readable_time = time.ctime(creation_time)
    print(f"The file was created on: {readable_time}")
    print(f"Original Format: {format}")
    current_time_seconds = time.time()
    local_time = time.strftime("%a %b %d %H:%M:%S %Y", time.localtime(current_time_seconds))
    conversion_log = pd.concat([conversion_log, pd.DataFrame([{
                        'File Name': name,
                        'Original Path': input,
                        'New Path': output,
                        'File Conversion': format,
                        'Original File Created': readable_time,
                        'New File Created': local_time,
                    }])], ignore_index=True)

# %%
def convert_files(folder_path):

    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} does not exist.")
        return
    global conversion_log
    contents = os.listdir(folder_path)
    
    for content in contents:
        
        content_path = os.path.join(folder_path, content)
        
        if os.path.isdir(content_path):
            print(f"Entering subfolder: {content_path}")
            create = content_path.replace("preservation", "access/nearline")
            os.makedirs(create,mode=0o775, exist_ok=True)
            convert_files(content_path)
        else:
            print("Found file:", content_path)
            
            if(content.endswith('.ws') or content.endswith('.WS')):
                try: 
                    
                    input_file = content_path
                    # new_name=content.replace('.', '_')
                    # new_file_path = os.path.join(content_path, new_name)
                    # os.rename(content_path, new_file_path)
                    output_file_name = f'{content}.md'
                    output_pdf_name = f'{content}.pdf'
                    folder_path = os.path.dirname(content_path)
                    output_file = os.path.join(folder_path, output_file_name)
                    output_file_pdf = os.path.join(folder_path, output_pdf_name)
                    output_file = transform_file_path(output_file)
                    
                    output_file_pdf = transform_file_path(output_file_pdf)
                    text_mode = False  # Set to True if you want unformatted (text) output
                    print("op md:",output_file)
                    print("op pdf:",output_file_pdf)
                    output_file_md = os.path.join(output_file, output_file_name)
                    output_file_pdf = os.path.join(output_file, output_pdf_name)
                    # Read file
                    print("Reading " + input_file)
                    with open(input_file, "rb") as infile:
                        data = infile.read()
                    
                    # Let's go through the file for some cleanup...
                    print("Converting...")
                    outdata = converttext(data)
                    
                    # Now decode the extended ASCII data...
                    outstring = outdata.decode("cp437")
                    
                    # Write to the output file
                    with open(output_file_md, "wt") as outfile:
                        outfile.write(outstring)
                    
                    print("Conversion ready, " + output_file_md + " written!")
                    convert_md_to_pdf(output_file_md, output_file_pdf)
                    conversion_log_modify(content, input_file, output_file_pdf, 'WordStar to PDF')
        
                except Exception as E:
                    print(E)
                    print("Could not convert!")

            elif(content.endswith('.mac') or content.endswith('.MAC') or content.endswith('.doc') or content.endswith('.DOC')):
                try: 
                        
                    input_file = content_path
                    name = content.replace('.mac', '')
                    name = name.replace('.MAC', '')
                    name = content.replace('.doc', '')
                    name = name.replace('.DOC', '')
                    output_file_name = f'{name}.pdf'
                    folder_path = os.path.dirname(content_path)
                    output_file = os.path.join(folder_path, output_file_name)
                    output_file = transform_file_path(output_file)
                    output_file_pdf = os.path.join(output_file, output_file_name)
                    print(output_file)
                    convert_mac(input_file, output_file_pdf)
                    conversion_log_modify(content, input_file, output_file_pdf, 'MacWrite to PDF')
            
                except Exception as E:
                    print(E)
                    print("Could not convert!")
            
            elif(content.endswith('.wpd') or content.endswith('.WPD')):
                try: 
                        
                    input_file = content_path
                    name = content.replace('.wpd', '')
                    name = name.replace('.WPD', '')
                    output_file_name = f'{name}.pdf'
                    folder_path = os.path.dirname(content_path)
                    output_file = os.path.join(folder_path, output_file_name)
                    output_file = transform_file_path(output_file)
                    output_file_pdf = os.path.join(output_file, output_file_name)
                    print(output_file)
                    convert_wpd_to_pdf(input_file, output_file_pdf)
                    conversion_log_modify(content, input_file, output_file_pdf, 'WordPerfect to PDF')
            
                except Exception as E:
                    print(E)
                    print("Could not convert!")
                    
            elif(content.endswith('.wk1') or content.endswith('.WK1')):
                try: 
                        
                    input_file = content_path
                    name = content.replace('.wk1', '')
                    name = name.replace('.WK1', '')
                    output_file_name = f'{name}.xlsx'
                    folder_path = os.path.dirname(content_path)
                    output_file = os.path.join(folder_path, output_file_name)
                    output_file = transform_file_path(output_file)
                    output_file_xl = os.path.join(output_file, output_file_name)
                    print(output_file)
                    convert_to_xlsx(input_file, output_file_xl)
                    conversion_log_modify(content, input_file, output_file_xl, 'Lotus 1-2-3 Spreadsheets to Excel Spreadsheet')
            
                except Exception as E:
                    print(E)
                    print("Could not convert!")

            elif(content.endswith('.wav') or content.endswith('.WAV')):
                try: 
                        
                    input_file = content_path
                    name = content.replace('.wav', '')
                    name = name.replace('.WAV', '')
                    output_file_name = f'{name}.mp3'
                    folder_path = os.path.dirname(content_path)
                    output_file = os.path.join(folder_path, output_file_name)
                    output_file = transform_file_path(output_file)
                    output_file_mp3 = os.path.join(output_file, output_file_name)
                    #print(output_file)
                    convert_wav_to_mp3(input_file, output_file_mp3)
                    conversion_log_modify(content, input_file, output_file_mp3, 'WAV to MP3')
            
                except Exception as E:
                    print(E)
                    print("Could not convert!")

# %%
# WordStar Only Functions

def convert_md_to_pdf(input_md_file, output_pdf_file):
    # Read Markdown content from file
    with open(input_md_file, 'r', encoding='utf-8') as md_file:
        md_content = md_file.read()

    # Convert Markdown to HTML
    html_content = markdown2.markdown(md_content)

    # Create PDF using WeasyPrint
    HTML(string=html_content).write_pdf(output_pdf_file)

def specialchars(x):
    return {
        0x0D : 0,    # skip newline handling
        0x0A : 0,
        0x19 : 0x2A, #italic
        0x13 : 0x2A, #underline->italic
        0x02 : 0x2A, #bold
        0x14 : 0x5E, #superscript
        0x16 : 0x7E, #subscript
        0x18 : 0x7E  #strikethrough
    }.get(x,0)

def handleblock(block):
    # implement here the handling of the blocks
    # block[0] is the length of the block (int)
    # block[2] is the command
    if block[2] == 0x03: # footer
        footerdata = converttext(block[20:]).replace(b'\n',b'')
        return b'^['+footerdata+b']'
    elif block[2] == 0x09: # TAB
        return b'    '
    elif block[2] == 0x11: # paragraph style
        if block[3] == 0x02: # header
            return b'## '
        elif block[3]== 0x05: #title
            return b'# '
    return b''

def converttext(data):
    counter = -1
    newline = False
    linetype = 0
    outdata = bytearray()
    while counter < len(data) - 1:
        counter += 1
        # End of file character
        if data[counter] == 0x1A:
            break
        # Extended character
        elif data[counter] == 0x1B:
            outdata.append(data[counter + 1])
            counter += 2
        # Symmetrical sequence: 1Dh special character
        elif data[counter] == 0x1D:
            jump = int.from_bytes(data[counter + 1:counter + 2], byteorder='little')
            outdata += handleblock(data[counter + 1:counter + jump])
            counter += jump + 2
        elif data[counter] < 0x20:  # special formatting characters
            if data[counter] == 0x0D and not newline:
                outdata += b'\x0D\x0A\x0D\x0A'
                newline = True
                linetype = 0
            # Note: Removed the reference to args.textmode since it's not used here
            c = specialchars(data[counter])
            if not c == 0:
                outdata.append(c)
            if data[counter] == 0x02 or data[counter] == 0x18:
                outdata.append(c)  # duplicating some characters ** and ~~
        elif data[counter] < 0x80:  # other characters
            if newline:
                newline = False
                if data[counter] == 0x2E:  # dotline
                    linetype = 1
            if linetype != 1:  # we are in a dotline => ignore it
                outdata.append(data[counter])
    return outdata

# %%
# MacWrite
def convert_mac(input_file, output_file):
    try:
        subprocess.run(["python", unoconv_path, "-f", "pdf", "-o", output_file, input_file], check=True)
        print("Conversion successful!")
    except subprocess.CalledProcessError as e:
        print(f"Error during conversion: {e}")

# %%
# Lotus 1-2-3 Charts to Excel Spreadsheet
def convert_to_xlsx(input_file, output_file):
    try:
        subprocess.run(["python", unoconv_path, '-f', 'xlsx', '-o', output_file, input_file], check=True)
        print(f"Successfully converted {input_file} to {output_file}")
    except subprocess.CalledProcessError as e:
        print(f"Error converting file: {e}")

# %%
def convert_wpd_to_pdf(input_path, output_path):
    try:
       
        if not output_path.lower().endswith(".pdf"):
            raise ValueError("Output file must have a .pdf extension.")

        # Check if unoconv is installed
        subprocess.run(["python", unoconv_path, "-f", "pdf", "-o", output_path, input_path], check=True)
        print(f"Conversion successful: {input_path} -> {output_path}")
        

    except Exception as e:
        print(f"Conversion failed: {e}")

# %%
def convert_wav_to_mp3(input_file, output_file, target_sr=44100):
    data, samplerate = sf.read(input_file)
    # Resample the audio data if the sample rate is not supported
    if samplerate != target_sr:
        num = target_sr
        den = samplerate
        data = resample_poly(data, num, den)
        samplerate = target_sr
    sf.write(output_file, data, samplerate, format='mp3')

# %%
path1 = r"C:\Users\pal10\Desktop\testcollection\preservation"

# %%
conversion_log = pd.DataFrame(columns=['File Name', 'Original Path', 'New Path', 'File Conversion', 'Original File Created', 'New File Created'])
path2 = path1.replace('preservation','ObjectDocumentation')
os.makedirs(path2,mode=0o775, exist_ok=True)

# %%
convert_files(path1)
# Out:
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall Interview
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall Interview\.ipynb_checkpoints
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall Interview\OriginalFiles
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall Interview\OriginalFiles\ZOOM0005.WAV
# C:\Users\pal10\Desktop\testcollection\access\nearline\30111WAV\Bill Hall Interview\OriginalFiles
# os.stat_result(st_mode=33206, st_ino=11540474045312646, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=558069248, st_atime=1715789814, st_mtime=1294549628, st_ctime=1715787136)
# ZOOM0005.WAV
# The file was created on: Sat Jan  8 23:07:08 2011
# Original Format: WAV to MP3
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall Interview\OriginalFiles\ZOOM0006.WAV
# C:\Users\pal10\Desktop\testcollection\access\nearline\30111WAV\Bill Hall Interview\OriginalFiles
# os.stat_result(st_mode=33206, st_ino=12103423998734541, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=471067136, st_atime=1715789868, st_mtime=1294552392, st_ctime=1715787137)
# ZOOM0006.WAV
# The file was created on: Sat Jan  8 23:53:12 2011
# Original Format: WAV to MP3
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall part 2
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall part 2\OriginalFiles
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall part 2\OriginalFiles\ZOOM0003.mp3
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall part 2\OriginalFiles\ZOOM0003.WAV
# C:\Users\pal10\Desktop\testcollection\access\nearline\30111WAV\Bill Hall part 2\OriginalFiles
# os.stat_result(st_mode=33206, st_ino=22236523160319037, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=16111104, st_atime=1715789911, st_mtime=1335652758, st_ctime=1715787138)
# ZOOM0003.WAV
# The file was created on: Sat Apr 28 17:39:18 2012
# Original Format: WAV to MP3
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall part 2\OriginalFiles\ZOOM0004.WAV
# C:\Users\pal10\Desktop\testcollection\access\nearline\30111WAV\Bill Hall part 2\OriginalFiles
# os.stat_result(st_mode=33206, st_ino=18014398509659909, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=271450112, st_atime=1715789913, st_mtime=1335654322, st_ctime=1715787138)
# ZOOM0004.WAV
# The file was created on: Sat Apr 28 18:05:22 2012
# Original Format: WAV to MP3
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30111WAV\Bill Hall part 2\OriginalFiles\ZOOM0005.WAV
# C:\Users\pal10\Desktop\testcollection\access\nearline\30111WAV\Bill Hall part 2\OriginalFiles
# os.stat_result(st_mode=33206, st_ino=5910974511101743, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=184876800, st_atime=1715789938, st_mtime=1335655776, st_ctime=1715787139)
# ZOOM0005.WAV
# The file was created on: Sat Apr 28 18:29:36 2012
# Original Format: WAV to MP3
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\action sheet.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=10133099161762802, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2144, st_atime=1715789961, st_mtime=1698771609, st_ctime=1715787139)
# action sheet.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\bump_tt promo.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=4222124650839123, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2604, st_atime=1715789967, st_mtime=1698771609, st_ctime=1715787139)
# bump_tt promo.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\call sheet.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=3940649674128675, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2054, st_atime=1715789973, st_mtime=1698771609, st_ctime=1715787139)
# call sheet.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\Chips bkgrd & phil.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=4785074604260750, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1924, st_atime=1715789978, st_mtime=1698771609, st_ctime=1715787139)
# Chips bkgrd & phil.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\CH_CH admin -staff.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=4503599627550425, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3018, st_atime=1715789984, st_mtime=1698771609, st_ctime=1715787139)
# CH_CH admin -staff.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\CH_CH front cover.mac
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=8444249301499670, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=11776, st_atime=1715789989, st_mtime=1698771609, st_ctime=1715787139)
# CH_CH front cover.mac
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\CH_CH quotes.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=19421773393215480, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1488, st_atime=1715789994, st_mtime=1698771609, st_ctime=1715787139)
# CH_CH quotes.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\ch_genl info.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=4503599627550753, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2244, st_atime=1715790000, st_mtime=1698771609, st_ctime=1715787139)
# ch_genl info.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\ch_mlr-cptns.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=3940649674129512, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1490, st_atime=1715790005, st_mtime=1698771609, st_ctime=1715787139)
# ch_mlr-cptns.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\ch_quotes.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=22799473113743525, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1378, st_atime=1715790011, st_mtime=1698771609, st_ctime=1715787139)
# ch_quotes.doc
# The file was created on: Tue Oct 31 12:00:09 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\contract for field trips.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=3940649674129625, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2840, st_atime=1715790016, st_mtime=1698771610, st_ctime=1715787139)
# contract for field trips.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\contract for tours.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=5629499534393704, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2696, st_atime=1715790022, st_mtime=1698771610, st_ctime=1715787139)
# contract for tours.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\David K. Smith.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=3940649674129977, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3608, st_atime=1715790028, st_mtime=1698771610, st_ctime=1715787139)
# David K. Smith.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\past shows.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=16607023626109851, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2508, st_atime=1715790033, st_mtime=1698771610, st_ctime=1715787139)
# past shows.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\RR-cover stuff 1.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=14073748835714040, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1528, st_atime=1715790038, st_mtime=1698771610, st_ctime=1715787139)
# RR-cover stuff 1.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\rr-nothing to do #1.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=14636698789135608, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=10540, st_atime=1715790044, st_mtime=1698771610, st_ctime=1715787139)
# rr-nothing to do #1.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\teletale.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=23925373020587498, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2254, st_atime=1715790049, st_mtime=1698771610, st_ctime=1715787139)
# teletale.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\301121023MWR\OriginalFiles\TT-rhrsl sched.doc
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# C:\Users\pal10\Desktop\testcollection\access\nearline\301121023MWR\OriginalFiles
# Conversion successful!
# os.stat_result(st_mode=33206, st_ino=11821949022029347, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3302, st_atime=1715790055, st_mtime=1698771610, st_ctime=1715787139)
# TT-rhrsl sched.doc
# The file was created on: Tue Oct 31 12:00:10 2023
# Original Format: MacWrite to PDF
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\ObjectDocumentation
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\ObjectDocumentation\diskTimestampInfo.txt.txt
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\ObjectDocumentation\ObjectJPG
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\ObjectDocumentation\ObjectJPG\30112119503834.JPG
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\AUTOEXEC.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\BBOX.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\BIBLIO.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\FL.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\HELP.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\INMAGIC.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\LIBRARY.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\LIBRBACK.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\MODAID.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\MODEL.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\MODEM.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\PHONE.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\R5K.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\SPREAD.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\STATS.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\SYSTEM.BAT
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\CBAK\BATFILES\WORD.BAT
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4GLEN2_PRN.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4GLEN2_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\4GLEN2_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1688849860877245, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2818, st_atime=1715790055, st_mtime=1688579234, st_ctime=1712081184)
# 4GLEN2_PRN.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4MAGLAST.WK1
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Successfully converted C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4MAGLAST.WK1 to C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\4MAGLAST.xlsx
# os.stat_result(st_mode=33206, st_ino=19421773393217284, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=6662, st_atime=1715790060, st_mtime=1473871688, st_ctime=1715787140)
# 4MAGLAST.WK1
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: Lotus 1-2-3 Spreadsheets to Excel Spreadsheet
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4USGS.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4USGS.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\4USGS.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\4USGS.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166592, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=4354, st_atime=1715790061, st_mtime=1688579234, st_ctime=1712081184)
# 4USGS.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\AP21HARR_LET.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\AP21HARR_LET.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\AP21HARR_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\AP21HARR_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1688849860877302, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1410, st_atime=1715790061, st_mtime=1688579234, st_ctime=1712081184)
# AP21HARR_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\ARTHUR_LET.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\ARTHUR_LET.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\ARTHUR_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\ARTHUR_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166649, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1666, st_atime=1715790061, st_mtime=1688579234, st_ctime=1712081184)
# ARTHUR_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\ASCII.WS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\ASCII.WS
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\ASCII.WS.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166650, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=8192, st_atime=1715790062, st_mtime=1688579234, st_ctime=1712081184)
# ASCII.WS
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT.BAK
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT.EVA
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT.GOA.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT_EVA.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT_GOA.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT_GOA.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT_GOA.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT_GOA.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166656, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1538, st_atime=1715790062, st_mtime=1688579234, st_ctime=1712081185)
# BLODGETT_GOA.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BLODGETT_RES.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BOATPART.txt
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BOATPART.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BOATPART.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\BOATPART.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166660, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=514, st_atime=1715790062, st_mtime=1688579234, st_ctime=1712081185)
# BOATPART.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BUDGET_INC.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\BUDGET_INC.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\BUDGET_INC.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166661, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=4610, st_atime=1715790062, st_mtime=1688579234, st_ctime=1712081185)
# BUDGET_INC.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF1-1_PRN.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF1-1_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CDF1-1_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166662, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1664, st_atime=1715790062, st_mtime=1688579234, st_ctime=1712081185)
# CDF1-1_PRN.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF1.WK1
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Successfully converted C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF1.WK1 to C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CDF1.xlsx
# os.stat_result(st_mode=33206, st_ino=1407374884166663, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3435, st_atime=1715790067, st_mtime=1473871688, st_ctime=1712081185)
# CDF1.WK1
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: Lotus 1-2-3 Spreadsheets to Excel Spreadsheet
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF2-1_PRN.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF2-1_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CDF2-1_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166664, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1280, st_atime=1715790067, st_mtime=1688579234, st_ctime=1712081185)
# CDF2-1_PRN.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF2.WK1
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Successfully converted C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDF2.WK1 to C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CDF2.xlsx
# os.stat_result(st_mode=33206, st_ino=1407374884166666, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2936, st_atime=1715790072, st_mtime=1473871688, st_ctime=1712081185)
# CDF2.WK1
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: Lotus 1-2-3 Spreadsheets to Excel Spreadsheet
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDFPRO1.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDFPRO1.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CDFPRO1.ws.md written!
# os.stat_result(st_mode=33206, st_ino=8444249301932539, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1715787213, st_mtime=1688579234, st_ctime=1712081185)
# CDFPRO1.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDFPRO2.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CDFPRO2.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CDFPRO2.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1688849860877323, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=6658, st_atime=1715790072, st_mtime=1688579234, st_ctime=1712081185)
# CDFPRO2.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CITATIO.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\CITATIO.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\CITATIO.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166668, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=258, st_atime=1715790073, st_mtime=1688579234, st_ctime=1712081185)
# CITATIO.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\COMPUTER.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\COMPUTER.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\COMPUTER.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166669, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2946, st_atime=1715790073, st_mtime=1688579234, st_ctime=1712081185)
# COMPUTER.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP.BAK
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP.WK1
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Successfully converted C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP.WK1 to C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP.xlsx
# os.stat_result(st_mode=33206, st_ino=1407374884166671, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3782, st_atime=1715790078, st_mtime=1473871690, st_ctime=1712081185)
# DIVEEQP.WK1
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: Lotus 1-2-3 Spreadsheets to Excel Spreadsheet
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP.WKS
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP_PRN.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\DIVEEQP_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166673, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2176, st_atime=1715790078, st_mtime=1473871688, st_ctime=1712081185)
# DIVEEQP_PRN.ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\EDDY2.BLK
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\EF.WK1
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Successfully converted C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\EF.WK1 to C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\EF.xlsx
# os.stat_result(st_mode=33206, st_ino=1407374884166675, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=5062, st_atime=1715790083, st_mtime=1473871688, st_ctime=1712081185)
# EF.WK1
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: Lotus 1-2-3 Spreadsheets to Excel Spreadsheet
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\EFBUD_PRN.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\EFBUD_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\EFBUD_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=9007199254812651, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3458, st_atime=1715790084, st_mtime=1688579234, st_ctime=1712081185)
# EFBUD_PRN.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\F11KRUSE_LET.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\F11KRUSE_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\F11KRUSE_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166676, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1538, st_atime=1715790084, st_mtime=1688579234, st_ctime=1712081185)
# F11KRUSE_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\F27GORDN_LET.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\F27GORDN_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\F27GORDN_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166677, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=6786, st_atime=1715790084, st_mtime=1688579234, st_ctime=1712081185)
# F27GORDN_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FENEMA_LET.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FENEMA_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\FENEMA_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166678, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1026, st_atime=1715790084, st_mtime=1688579234, st_ctime=1712081185)
# FENEMA_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FISHFIND.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FISHFIND.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\FISHFIND.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166679, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3714, st_atime=1715790084, st_mtime=1688579234, st_ctime=1712081185)
# FISHFIND.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FISHSWIM_LET.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FISHSWIM_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\FISHSWIM_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166680, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1026, st_atime=1715790085, st_mtime=1688579234, st_ctime=1712081185)
# FISHSWIM_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FLTTIME.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FLTTIME.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\FLTTIME.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166681, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1538, st_atime=1715790085, st_mtime=1688579234, st_ctime=1712081185)
# FLTTIME.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FONTS.BAK
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FONTS.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op pdf: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# Reading C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\FONTS.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS\FONTS.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1407374884166683, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1152, st_atime=1715790085, st_mtime=1473871688, st_ctime=1712081185)
# FONTS.ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119503834\OriginalFiles\DOUGS\DISKS\HEADER.ws
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# op md: C:\Users\pal10\Desktop\testcollection\access\nearline\30112119503834\OriginalFiles\DOUGS\DISKS
# ...
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\1PROJS\WETSUIT\WETSUIT5.ABS
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\1PROJS\WETSUIT\WETSUIT5.WPF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\1PROJS\WETSUIT\WETSUIT6.WPF
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB001.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB001.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB002.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB002.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB003.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB003.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB004.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB004.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB005.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB005.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB006.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB006.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB007.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB007.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB008.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB008.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB009.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB009.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB010.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB010.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB011.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB011.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB012.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB012.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB013.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB013.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB014.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\CALEB014.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PERSONAL\PICTURS\CALEB\GOLF.PRE
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\001.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\002.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\004.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\005.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\008.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\009.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\011.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\012.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\013.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\021.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\022.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\03.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN001.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN002.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN003.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN004.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN005.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN006.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN007.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN008.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN009.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN010.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN011.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN012.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN013.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN014.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN015.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN016.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN017.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN018.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN019.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN020.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN021.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN022.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\QVLIN023.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\BOLTONIA\Thumbs.db
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT001.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT002.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT003.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT004.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT005.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT006.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT007.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT008.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT009.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT010.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT011.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT012.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT013.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT014.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT015.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT016.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT017.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT018.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT019.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT020.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT021.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT022.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\DIGIT023.TIF
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE004.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE005.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE006.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE007.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE008.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE009.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE010.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE011.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE012.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE013.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE014.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE015.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE016.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE017.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE018.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE019.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE020.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE021.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE022.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE023.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE024.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE025.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\FISH\WINTER97\WINTE026.CAM
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\INVERTS
# Entering subfolder: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\INVERTS\WINTER97
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\INVERTS\WINTER97\WINTE001.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\INVERTS\WINTER97\WINTE002.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\INVERTS\WINTER97\WINTE003.CAM
# Found file: C:\Users\pal10\Desktop\testcollection\preservation\30112119504998\OriginalFiles\PICTURES\INVERTS\WINTER97\WINTE016.CAM

# %%
print(conversion_log)
# Out:
#         File Name                                      Original Path  \
# 0    ZOOM0005.WAV  C:\Users\pal10\Desktop\testcollection\preserva...
# 1    ZOOM0006.WAV  C:\Users\pal10\Desktop\testcollection\preserva...
# 2    ZOOM0003.WAV  C:\Users\pal10\Desktop\testcollection\preserva...
# 3    ZOOM0004.WAV  C:\Users\pal10\Desktop\testcollection\preserva...
# 4    ZOOM0005.WAV  C:\Users\pal10\Desktop\testcollection\preserva...
# ..            ...                                                ...
# 335  TOXINDX2.WK1  C:\Users\pal10\Desktop\testcollection\preserva...
# 336  TUBERWTS.WK1  C:\Users\pal10\Desktop\testcollection\preserva...
# 337  VAL12391.WK1  C:\Users\pal10\Desktop\testcollection\preserva...
# 338  VALDAT91.WK1  C:\Users\pal10\Desktop\testcollection\preserva...
# 339  WETSUIT2.WK1  C:\Users\pal10\Desktop\testcollection\preserva...
#
#                                               New Path  \
# 0    C:\Users\pal10\Desktop\testcollection\access\n...
# 1    C:\Users\pal10\Desktop\testcollection\access\n...
# 2    C:\Users\pal10\Desktop\testcollection\access\n...
# 3    C:\Users\pal10\Desktop\testcollection\access\n...
# 4    C:\Users\pal10\Desktop\testcollection\access\n...
# ..                                                 ...
# 335  C:\Users\pal10\Desktop\testcollection\access\n...
# 336  C:\Users\pal10\Desktop\testcollection\access\n...
# 337  C:\Users\pal10\Desktop\testcollection\access\n...
# 338  C:\Users\pal10\Desktop\testcollection\access\n...
# 339  C:\Users\pal10\Desktop\testcollection\access\n...
#
#                                    File Conversion     Original File Created  \
# 0                                       WAV to MP3  Sat Jan  8 23:07:08 2011
# 1                                       WAV to MP3  Sat Jan  8 23:53:12 2011
# 2                                       WAV to MP3  Sat Apr 28 17:39:18 2012
# 3                                       WAV to MP3  Sat Apr 28 18:05:22 2012
# 4                                       WAV to MP3  Sat Apr 28 18:29:36 2012
# ..                                             ...                       ...
# 335  Lotus 1-2-3 Spreadsheets to Excel Spreadsheet  Tue Mar 29 09:41:02 1988
# 336  Lotus 1-2-3 Spreadsheets to Excel Spreadsheet  Thu Apr 30 06:07:50 1992
# 337  Lotus 1-2-3 Spreadsheets to Excel Spreadsheet  Thu Jan 30 09:19:54 1992
# 338  Lotus 1-2-3 Spreadsheets to Excel Spreadsheet  Mon Feb 17 07:50:04 1992
# 339  Lotus 1-2-3 Spreadsheets to Excel Spreadsheet  Fri Feb 10 03:00:52 1995
#
#              New File Created
# 0    Wed May 15 11:17:46 2024
# 1    Wed May 15 11:18:30 2024
# 2    Wed May 15 11:18:32 2024
# 3    Wed May 15 11:18:58 2024
# 4    Wed May 15 11:19:15 2024
# ..                        ...
# 335  Wed May 15 11:35:54 2024
# 336  Wed May 15 11:36:00 2024
# 337  Wed May 15 11:36:06 2024
# 338  Wed May 15 11:36:12 2024
# 339  Wed May 15 11:36:17 2024
#
# [340 rows x 6 columns]

# %%
csv_path = os.path.join(path2, 'Conversion_Log.csv')
conversion_log.to_csv(csv_path, index=False)
