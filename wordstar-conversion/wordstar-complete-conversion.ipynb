# %%
import subprocess
import os
import sys
import shutil
import argparse
import xlrd
from openpyxl import Workbook
import markdown2
from weasyprint import HTML
import stat
import time
import pandas as pd

# %%
def transform_file_path(file_path):

    components = file_path.split(os.sep)
    
    preservation_index = components.index('preservation')
    
    components[preservation_index] = r"access\nearline"
    access = r"access\nearline"
    new_file_path = os.sep.join(components[:-1])  # Remove the last directory
    #new_file_path = os.path.join(new_file_path, access)
    print(new_file_path)
    return new_file_path

def conversion_log_modify(name, input, output, format):
    global conversion_log
    file_stat = os.stat(input)
    print(file_stat)
    print(name)
    creation_time = file_stat.st_mtime
    # Convert to a human-readable format
    readable_time = time.ctime(creation_time)
    print(f"The file was created on: {readable_time}")
    print(f"Original Format: {format}")
    current_time_seconds = time.time()
    local_time = time.strftime("%a %b %d %H:%M:%S %Y", time.localtime(current_time_seconds))
    conversion_log = pd.concat([conversion_log, pd.DataFrame([{
                        'File Name': name,
                        'Original Path': input,
                        'New Path': output,
                        'File Conversion': format,
                        'Original File Created': readable_time,
                        'New File Created': local_time,
                    }])], ignore_index=True)

    

def convert_files(folder_path):

    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} does not exist.")
        return
    global conversion_log
    contents = os.listdir(folder_path)
    
    for content in contents:
        
        content_path = os.path.join(folder_path, content)
        
        if os.path.isdir(content_path):
            print(f"Entering subfolder: {content_path}")
            create = content_path.replace("preservation", "access/nearline")
            os.makedirs(create,mode=0o775, exist_ok=True)
            convert_files(content_path)
        else:
            print("Found file:", content_path)
            if(content.endswith('.ws') or content.endswith('.WS')):
                try: 
                    
                    input_file = content_path
                    # new_name=content.replace('.', '_')
                    # new_file_path = os.path.join(content_path, new_name)
                    # os.rename(content_path, new_file_path)
                    output_file_name = f'{content}.md'
                    output_pdf_name = f'{content}.pdf'
                    folder_path = os.path.dirname(content_path)
                    output_file = os.path.join(folder_path, output_file_name)
                    output_file_pdf = os.path.join(folder_path, output_pdf_name)
                    output_file = transform_file_path(output_file)
                    
                    output_file_pdf = transform_file_path(output_file_pdf)
                    text_mode = False  # Set to True if you want unformatted (text) output
                    print("op md:",output_file)
                    print("op pdf:",output_file_pdf)
                    output_file_md = os.path.join(output_file, output_file_name)
                    output_file_pdf = os.path.join(output_file, output_pdf_name)
                    # Read file
                    print("Reading " + input_file)
                    with open(input_file, "rb") as infile:
                        data = infile.read()
                    
                    # Let's go through the file for some cleanup...
                    print("Converting...")
                    outdata = converttext(data)
                    
                    # Now decode the extended ASCII data...
                    outstring = outdata.decode("cp437")
                    
                    # Write to the output file
                    with open(output_file_md, "wt") as outfile:
                        outfile.write(outstring)
                    
                    print("Conversion ready, " + output_file_md + " written!")
                    convert_md_to_pdf(output_file_md, output_file_pdf)
                    conversion_log_modify(content, input_file, output_file_pdf, 'WordStar to PDF')
        
                except Exception as E:
                    print(E)
                    print("Could not convert!")

# %%
# WordStar Only Functions

def convert_md_to_pdf(input_md_file, output_pdf_file):
    # Read Markdown content from file
    with open(input_md_file, 'r', encoding='utf-8') as md_file:
        md_content = md_file.read()

    # Convert Markdown to HTML
    html_content = markdown2.markdown(md_content)

    # Create PDF using WeasyPrint
    HTML(string=html_content).write_pdf(output_pdf_file)

def specialchars(x):
    return {
        0x0D : 0,    # skip newline handling
        0x0A : 0,
        0x19 : 0x2A, #italic
        0x13 : 0x2A, #underline->italic
        0x02 : 0x2A, #bold
        0x14 : 0x5E, #superscript
        0x16 : 0x7E, #subscript
        0x18 : 0x7E  #strikethrough
    }.get(x,0)

def handleblock(block):
    # implement here the handling of the blocks
    # block[0] is the length of the block (int)
    # block[2] is the command
    if block[2] == 0x03: # footer
        footerdata = converttext(block[20:]).replace(b'\n',b'')
        return b'^['+footerdata+b']'
    elif block[2] == 0x09: # TAB
        return b'    '
    elif block[2] == 0x11: # paragraph style
        if block[3] == 0x02: # header
            return b'## '
        elif block[3]== 0x05: #title
            return b'# '
    return b''

def converttext(data):
    counter = -1
    newline = False
    linetype = 0
    outdata = bytearray()
    while counter < len(data) - 1:
        counter += 1
        # End of file character
        if data[counter] == 0x1A:
            break
        # Extended character
        elif data[counter] == 0x1B:
            outdata.append(data[counter + 1])
            counter += 2
        # Symmetrical sequence: 1Dh special character
        elif data[counter] == 0x1D:
            jump = int.from_bytes(data[counter + 1:counter + 2], byteorder='little')
            outdata += handleblock(data[counter + 1:counter + jump])
            counter += jump + 2
        elif data[counter] < 0x20:  # special formatting characters
            if data[counter] == 0x0D and not newline:
                outdata += b'\x0D\x0A\x0D\x0A'
                newline = True
                linetype = 0
            # Note: Removed the reference to args.textmode since it's not used here
            c = specialchars(data[counter])
            if not c == 0:
                outdata.append(c)
            if data[counter] == 0x02 or data[counter] == 0x18:
                outdata.append(c)  # duplicating some characters ** and ~~
        elif data[counter] < 0x80:  # other characters
            if newline:
                newline = False
                if data[counter] == 0x2E:  # dotline
                    linetype = 1
            if linetype != 1:  # we are in a dotline => ignore it
                outdata.append(data[counter])
    return outdata

# %%
path1 = r"C:\Users\pal10\Desktop\preservation"

# %%
conversion_log = pd.DataFrame(columns=['File Name', 'Original Path', 'New Path', 'File Conversion', 'Original File Created', 'New File Created'])
path2 = path1.replace('preservation','ObjectDocumentation')
os.makedirs(path2,mode=0o775, exist_ok=True)

# %%
convert_files(path1)
# Out:
# Entering subfolder: C:\Users\pal10\Desktop\preservation\DISKS
# Entering subfolder: C:\Users\pal10\Desktop\preservation\DISKS\.ipynb_checkpoints
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\4GLEN2_PRN.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\4GLEN2_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\4GLEN2_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3377699720805582, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2818, st_atime=1715792524, st_mtime=1688579234, st_ctime=1708975708)
# 4GLEN2_PRN.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\4MAGLAST.WK1
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\4USGS.txt
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\4USGS.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\4USGS.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\4USGS.ws.md written!
# os.stat_result(st_mode=33206, st_ino=9851624185168784, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=4354, st_atime=1715792524, st_mtime=1688579234, st_ctime=1708975708)
# 4USGS.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\AP21HARR_LET.txt
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\AP21HARR_LET.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\AP21HARR_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\AP21HARR_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=2533274790691956, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1410, st_atime=1715792524, st_mtime=1688579234, st_ctime=1708975708)
# AP21HARR_LET.ws
# The file was created on: Wed Jul  5 12:47:14 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\ARTHUR_LET.txt
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\ARTHUR_LET.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\ARTHUR_LET.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\ARTHUR_LET.ws.md written!
# os.stat_result(st_mode=33206, st_ino=2814749767402643, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=
st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=768, st_atime=1715792537, st_mtime=1473871688, st_ctime=1708975709)
# MUSNEWS.ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\MUSPRES_MEM.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\MUSPRES_MEM.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\MUSPRES_MEM.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1688849860560453, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1024, st_atime=1715792537, st_mtime=1473871690, st_ctime=1708975709)
# MUSPRES_MEM.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\MUSSUM.BAK
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\MUSSUM.WK1
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\MUSSUM_PRN.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\MUSSUM_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\MUSSUM_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=2814749767403083, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3456, st_atime=1715792537, st_mtime=1473871690, st_ctime=1708975709)
# MUSSUM_PRN.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\NEWLIST4.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\NEWLIST4.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\NEWLIST4.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3377699720824398, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=22144, st_atime=1715792538, st_mtime=1473871690, st_ctime=1708975709)
# NEWLIST4.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\PAR4REP.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\PAR4REP.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\PAR4REP.ws.md written!
# os.stat_result(st_mode=33206, st_ino=2814749767403087, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=3712, st_atime=1715792539, st_mtime=1473871688, st_ctime=1708975709)
# PAR4REP.ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\PETELAST_PRN.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\PETELAST_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\PETELAST_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3096224744113746, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2028, st_atime=1715792539, st_mtime=1688579235, st_ctime=1708975709)
# PETELAST_PRN.ws
# The file was created on: Wed Jul  5 12:47:15 2023
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\PHEC_ABS.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\PHEC_ABS.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\PHEC_ABS.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3659174697535061, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=2304, st_atime=1715792539, st_mtime=1473871690, st_ctime=1708975709)
# PHEC_ABS.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\PUTER.WK1
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\PUTER1_PRN.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\PUTER1_PRN.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\PUTER1_PRN.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3940649674245734, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1920, st_atime=1715792539, st_mtime=1473871690, st_ctime=1708975709)
# PUTER1_PRN.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\PUTERSEP.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\PUTERSEP.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\PUTERSEP.ws.md written!
# os.stat_result(st_mode=33206, st_ino=4222124650956393, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1664, st_atime=1715792540, st_mtime=1473871688, st_ctime=1708975709)
# PUTERSEP.ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\RICKSCV.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\RICKSCV.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\RICKSCV.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3377699720824429, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=60672, st_atime=1715792540, st_mtime=1473871690, st_ctime=1708975709)
# RICKSCV.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\RIP.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\RIP.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\RIP.ws.md written!
# os.stat_result(st_mode=33206, st_ino=3659174697535086, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1536, st_atime=1715792541, st_mtime=1473871690, st_ctime=1708975709)
# RIP.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\SCHED.WK1
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\TEMP1.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\TEMP1.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\TEMP1.ws.md written!
# os.stat_result(st_mode=33206, st_ino=1688849860560500, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=640, st_atime=1715792541, st_mtime=1473871690, st_ctime=1708975709)
# TEMP1.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\TIMELFT.WK1
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\UIMED.ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\UIMED.ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\UIMED.ws.md written!
# os.stat_result(st_mode=33206, st_ino=2251799813981815, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=4480, st_atime=1715792542, st_mtime=1473871690, st_ctime=1708975709)
# UIMED.ws
# The file was created on: Wed Sep 14 11:48:10 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\UMRBAMEM..ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\UMRBAMEM..ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\UMRBAMEM..ws.md written!
# os.stat_result(st_mode=33206, st_ino=2533274790692472, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=1408, st_atime=1715792542, st_mtime=1473871688, st_ctime=1708975709)
# UMRBAMEM..ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS\UMRLENT..ws
# C:\Users\pal10\Desktop\access\nearline\DISKS
# C:\Users\pal10\Desktop\access\nearline\DISKS
# op md: C:\Users\pal10\Desktop\access\nearline\DISKS
# op pdf: C:\Users\pal10\Desktop\access\nearline\DISKS
# Reading C:\Users\pal10\Desktop\preservation\DISKS\UMRLENT..ws
# Converting...
# Conversion ready, C:\Users\pal10\Desktop\access\nearline\DISKS\UMRLENT..ws.md written!
# os.stat_result(st_mode=33206, st_ino=2814749767403134, st_dev=16016024109827288881, st_nlink=1, st_uid=0, st_gid=0, st_size=10368, st_atime=1715792542, st_mtime=1473871688, st_ctime=1708975709)
# UMRLENT..ws
# The file was created on: Wed Sep 14 11:48:08 2016
# Original Format: WordStar to PDF
# Found file: C:\Users\pal10\Desktop\preservation\DISKS
# 65  C:\Users\pal10\Desktop\access\nearline\DISKS\U...  WordStar to PDF
# 66  C:\Users\pal10\Desktop\access\nearline\DISKS\W...  WordStar to PDF
# 67  C:\Users\pal10\Desktop\access\nearline\DISKS\W...  WordStar to PDF
# 68  C:\Users\pal10\Desktop\access\nearline\DISKS\W...  WordStar to PDF
# 69  C:\Users\pal10\Desktop\access\nearline\DISKS\W...  WordStar to PDF
#
#        Original File Created          New File Created
# 0   Wed Jul  5 12:47:14 2023  Wed May 15 12:02:04 2024
# 1   Wed Jul  5 12:47:14 2023  Wed May 15 12:02:04 2024
# 2   Wed Jul  5 12:47:14 2023  Wed May 15 12:02:04 2024
# 3   Wed Jul  5 12:47:14 2023  Wed May 15 12:02:05 2024
# 4   Wed Jul  5 12:47:14 2023  Wed May 15 12:02:05 2024
# ..                       ...                       ...
# 65  Wed Sep 14 11:48:08 2016  Wed May 15 12:02:22 2024
# 66  Wed Sep 14 11:48:08 2016  Wed May 15 12:02:23 2024
# 67  Wed Sep 14 11:48:10 2016  Wed May 15 12:02:23 2024
# 68  Wed Jul  5 12:47:15 2023  Wed May 15 12:02:24 2024
# 69  Wed Sep 14 11:48:08 2016  Wed May 15 12:02:24 2024
#
# [70 rows x 6 columns]

# %%
print(path2)
# Out:
# C:\Users\pal10\Desktop\ObjectDocumentation

# %%
currenttime = time.localtime()
dateconverted = time.strftime("%Y%m%d%H%M%S", currenttime)
csv_path = os.path.join(path2, f'Conversion_Log_{dateconverted}.csv')
print(csv_path)
# Out:
# C:\Users\pal10\Desktop\ObjectDocumentation\Conversion_Log_20240515120334.csv

# %%
conversion_log.to_csv(csv_path, index=False)

# %%
# def process_file(content, content_path, folder_path, conversion_log):
#     try:
#         if content.lower().endswith(('.mac', '.wpd', '.wk1', '.ws', '.wav')):
#             base_name = os.path.splitext(content)[0]
#             output_file_name = f'{base_name}.pdf' if not content.lower().endswith('.wav') else f'{base_name}.mp3'
#             access_path = transform_file_path(folder_path)
#             output_file = os.path.join(access_path, output_file_name)
#             # Fake conversion function to be replaced with actual implementation
#             convert_dummy(content_path, output_file)
#             conversion_log.append({
#                 'Original Path': content_path,
#                 'New Path': output_file,
#                 'File Type': content.split('.')[-1].upper() + ' to ' + ('PDF' if not content.lower().endswith('.wav') else 'MP3'),
#                 'Status': 'Success',
#                 'Error Message': ''
#             }, ignore_index=True)
#             print("Conversion successful for:", content_path)
#     except Exception as e:
#         conversion_log.append({
#             'Original Path': content_path,
#             'New Path': output_file,
#             'File Type': content.split('.')[-1].upper() + ' to ' + ('PDF' if not content.lower().endswith('.wav') else 'MP3'),
#             'Status': 'Failed',
#             'Error Message': str(e)
#         }, ignore_index=True)
#         print("Failed to convert:", content_path, "Error:", str(e))

# def convert_dummy(input_file, output_file):
#     # Dummy conversion logic to simulate the process
#     print(f"Converting {input_file} to {output_file}")

# # Start of the script
# conversion_log = pd.DataFrame(columns=['Original Path', 'New Path', 'File Type', 'Status', 'Error Message'])
# path1 = r"C:\Users\pal10\Desktop\testcollection\preservation"
# conversion_log = convert_files(path1, conversion_log)
# conversion_log.to_csv('conversion_log.csv', index=False)
